# %%
import scipy.io as scio
# import pandas as pd
data_path = "./data/sineShape2"
data = scio.loadmat(data_path)
datas = data.get('demos')#取出字典里的label
print(datas)
# Out:
# [[array([[-9.87836022e+00, -9.87836022e+00, -9.85954301e+00,
#         -9.79368280e+00, -9.71841398e+00, -9.62432796e+00,
#         -9.49260753e+00, -9.37970430e+00, -9.23857527e+00,
#         -9.14448925e+00, -9.03158602e+00, -8.91868280e+00,
#         -8.77755376e+00, -8.64583333e+00, -8.22244624e+00,
#         -7.99663978e+00, -7.88373656e+00, -7.78965054e+00,
#         -7.62970430e+00, -7.43212366e+00, -7.28158602e+00,
#         -7.16868280e+00, -7.03696237e+00, -6.85819892e+00,
#         -6.79233871e+00, -6.71706989e+00, -6.57594086e+00,
#         -6.39717742e+00, -6.23723118e+00, -6.07728495e+00,
#         -5.96438172e+00, -5.85147849e+00, -5.71975806e+00,
#         -5.55981183e+00, -5.40927419e+00, -5.30577957e+00,
#         -5.19287634e+00, -5.03293011e+00, -4.91061828e+00,
#         -4.77889785e+00, -4.69422043e+00, -4.53427419e+00,
#         -4.30846774e+00, -4.09206989e+00, -3.97916667e+00,
#         -3.81922043e+00, -3.64986559e+00, -3.49932796e+00,
# ...

# %%
# print(type(datas.ravel()))
# print(datas.ravel().shape)
# print(datas.shape)
import numpy as np
aa = list(data.T for data in datas.ravel())
# print(aa[0].shape)
bb = np.concatenate(aa, axis=0)
print(bb.shape)
# print(datas[0,0].shape)
# print(type(datas[0,0]))
# Out:
# (623, 2)
